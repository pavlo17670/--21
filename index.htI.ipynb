# %%
<!DOCTYPE html>
<html lang="uk">
<head>
    <meta charset="UTF-8">
    <title>Моє хобі</title>
</head>
<body>

    <nav>
        <a href="index.html">Головна</a> |
        <a href="info.html">Про моє хобі</a>
    </nav>

    <h1>Моє хобі — мотоцикли</h1>

    <h2>Чому я люблю мотоцикли</h2>

    <p>
        Мотоцикли — це моє улюблене захоплення.
        <strong>Вони дарують відчуття свободи та адреналіну.</strong>
    </p>

    <p>
        Я люблю проводити час із мотоциклом, доглядати за ним і кататися.
        <em>Для мене це не просто транспорт, а справжнє хобі.</em>
        <br>
        Кожна поїздка приносить нові враження.
    </p>

    <hr>

    <h3 id="benefits">Що мені подобається в цьому хобі</h3>

    <ul>
        <li>Швидкість і динаміка</li>
        <li>Відчуття свободи</li>
        <li>Ремонт і догляд за мотоциклом</li>
        <li>Подорожі та нові місця</li>
    </ul>

    <h3>Як я займаюся своїм хобі</h3>

    <ol>
        <li>Перевіряю технічний стан мотоцикла.</li>
        <li>Доглядаю та ремонтую його.</li>
        <li>Виїжджаю покататися.</li>
    </ol>

    <div>
        <h2>Дізнайся більше</h2>
        <p>На інформаційній сторінці можна дізнатися більше про моє хобі.</p>
        <button onclick="location.href='info.html'">Перейти до інформації</button>
    </div>

    <figure>
        <img src="images/image.jpg" alt="Мотоцикл" width="500">
        <figcaption>Мотоцикл — моє улюблене захоплення</figcaption>
    </figure>

    <p>
        <a href="https://uk.wikipedia.org/wiki/Мотоцикл" target="_blank">
            Дізнатися більше про мотоцикли
        </a>
    </p>

    <p>
        <a href="#benefits">Перейти до розділу «Що мені подобається»</a>
    </p>

</body>
</html>
